# %%
import pandas as pd
import datetime
import numpy as np

# %%
df = pd.read_csv('https://www.web.statistik.zh.ch/ogd/data/ji/fk/kultur_ausfallentschaedigung.csv')

# %% [markdown]
# ### Was ist im Datensatz?

# %%
print('Anzahl Gesuche im Datensatz: ' + str(len(df)))
# Out:
# Anzahl Gesuche im Datensatz: 1611

# %%
print('Welche Sparte hat wie viele Gesuch gestellt')
df['Sparte'].value_counts()
# Out:
# Welche Sparte hat wie viele Gesuch gestellt
# Musik                      771
# Tanz/Theater               306
# Bereichsübergreifend       124
# Film                       107
# Bildende Kunst             104
# Klubs und Konzertlokale     79
# Literatur                   44
# Kino                        30
# Design                      29
# Museen                      17
# Name: Sparte, dtype: int64

# %%
print('Welche Kategorie hat wie viele Gesuch gestellt')
df['Kategorie'].value_counts()
# Out:
# Welche Kategorie hat wie viele Gesuch gestellt
# Kulturschaffende                      1027
# Kulturunternehmen gewinnorientiert     354
# Kulturunternehmen gemeinnützig         230
# Name: Kategorie, dtype: int64

# %% [markdown]
# ### Wie viele Gesuche wurden angenommen/abgelehnt?

# %%
print('Anteile ausbezahlter und abgelehnter Geusche:')
df.Status.value_counts('normalize')*100
# Out:
# Anteile ausbezahlter und abgelehnter Geusche:
# Ausbezahlt     80.571074
# Ablehnung      19.180633
# Saldo offen     0.248293
# Name: Status, dtype: float64

# %%
print('Anteile ausbezahlter und abgelehnter Geusche innerhalb der Kategorien:')
df[['Kategorie','Sparte','Status',]].groupby('Kategorie')['Status'].value_counts('normalize')*100
# Out:
# Anteile ausbezahlter und abgelehnter Geusche innerhalb der Kategorien:
# Kategorie                           Status
# Kulturschaffende                    Ausbezahlt     80.136319
#                                     Ablehnung      19.668939
#                                     Saldo offen     0.194742
# Kulturunternehmen gemeinnützig      Ausbezahlt     86.086957
#                                     Ablehnung      13.913043
# Kulturunternehmen gewinnorientiert  Ausbezahlt     78.248588
#                                     Ablehnung      21.186441
#                                     Saldo offen     0.564972
# Name: Status, dtype: float64

# %%
print('Anteile ausbezahlter und abgelehnter Geusche über die Sparten:')
df[['Kategorie','Sparte','Status',]].groupby('Sparte')['Status'].value_counts('normalize')*100
# Out:
# Anteile ausbezahlter und abgelehnter Geusche über die Sparten:
# Sparte                   Status
# Bereichsübergreifend     Ausbezahlt     78.225806
#                          Ablehnung      21.774194
# Bildende Kunst           Ausbezahlt     57.692308
#                          Ablehnung      42.307692
# Design                   Ausbezahlt     55.172414
#                          Ablehnung      44.827586
# Film                     Ausbezahlt     66.355140
#                          Ablehnung      33.644860
# Kino                     Ausbezahlt     93.333333
#                          Ablehnung       6.666667
# Klubs und Konzertlokale  Ausbezahlt     84.810127
#                          Ablehnung      15.189873
# Literatur                Ausbezahlt     84.090909
#                          Ablehnung      15.909091
# Museen                   Ausbezahlt     76.470588
#                          Ablehnung      23.529412
# Musik                    Ausbezahlt     87.029831
#                          Ablehnung      12.451362
#                          Saldo offen     0.518807
# Tanz/Theater             Ausbezahlt     77.777778
#                          Ablehnung      22.222222
# Name: Status, dtype: float64

# %%
df_bew = df[df['Status']=='Ausbezahlt']
df_ab = df[df['Status']=='Ablehnung']
#df = df[df['Status']!='Saldo offen']

# %% [markdown]
# ### Wer hat wie viel bekommen?

# %%
print('Differenz und Auszahlung nach Kategorie')
df_kat = df_bew.groupby('Kategorie').sum()
df_kat['differenz'] = df_kat['Beschluss']-df_kat['Nachgefragt']
df_kat
# Out:
# Differenz und Auszahlung nach Kategorie
#                                     Nachgefragt   Beschluss   differenz
# Kategorie
# Kulturschaffende                       16111000   6596400.0  -9514600.0
# Kulturunternehmen gemeinnützig         22097600  13071900.0  -9025700.0
# Kulturunternehmen gewinnorientiert     94719600  40791200.0 -53928400.0

# %%
print('Differenz und Auszahlung nach Sparte')

df_sparte = df_bew.groupby('Sparte').sum()
df_sparte['differenz'] = df_sparte['Beschluss']-df_sparte['Nachgefragt']
df_sparte.sort_values('Beschluss',ascending=False)
# Out:
# Differenz und Auszahlung nach Sparte
#                          Nachgefragt   Beschluss   differenz
# Sparte
# Musik                       39547100  17456300.0 -22090800.0
# Tanz/Theater                17242800   9318200.0  -7924600.0
# Klubs und Konzertlokale     23370400   8388900.0 -14981500.0
# Film                        12858500   8350800.0  -4507700.0
# Kino                        20016100   7140100.0 -12876000.0
# Bereichsübergreifend        12409100   6507800.0  -5901300.0
# Bildende Kunst               3651100   1464400.0  -2186700.0
# Museen                       2678800   1292400.0  -1386400.0
# Design                        663100    361100.0   -302000.0
# Literatur                     491200    179500.0   -311700.0

# %%
print('Differenz und Auszahlung nach Sparte und Kategorie')
df_sparte = df_bew.groupby(['Kategorie','Sparte']).sum()
df_sparte['differenz'] = df_sparte['Beschluss']-df_sparte['Nachgefragt']
df_sparte.sort_values('Beschluss',ascending=False)
# Out:
# Differenz und Auszahlung nach Sparte und Kategorie
#                                                             Nachgefragt  \
# Kategorie                          Sparte
# Kulturunternehmen gewinnorientiert Musik                       22738300
#                                    Klubs und Konzertlokale     22908100
#                                    Film                        11208000
#                                    Kino                        19097900
# Kulturunternehmen gemeinnützig     Musik                        8154600
# Kulturunternehmen gewinnorientiert Tanz/Theater                 9002200
#                                    Bereichsübergreifend         9418000
# Kulturschaffende                   Musik                        8654200
# Kulturunternehmen gemeinnützig     Tanz/Theater                 4379500
# Kulturschaffende                   Tanz/Theater                 3861100
# Kulturunternehmen gemeinnützig     Bereichsübergreifend         2229100
#                                    Museen                       2601500
#                                    Bildende Kunst               1933000
#                                    Film                         1133200
# Kulturschaffende                   Bildende Kunst               1718100
# Kulturunternehmen gemeinnützig     Kino                          918200
# Kulturschaffende                   Bereichsübergreifend          762000
#                                    Film                          517300
# Kulturunternehmen gemeinnützig     Klubs und Konzertlokale       462300
#                                    Design                        140000
# Kulturschaffende                   Design                        295100
# Kulturunternehmen gemeinnützig     Literatur                     146200
# Kulturunternehmen gewinnorientiert Design                        228000
# Kulturschaffende                   Literatur                     303200
# Kulturunternehmen gewinnorientiert Museen                         77300
#                                    Literatur                      41800
#
#                                                             Beschluss  \
# Kategorie                          Sparte
# Kulturunternehmen gewinnorientiert Musik                    8327000.0
#                                    Klubs und Konzertlokale  8157400.0
#                                    Film                     7407400.0
#                                    Kino                     6758600.0
# Kulturunternehmen gemeinnützig     Musik                    5298100.0
# Kulturunternehmen gewinnorientiert Tanz/Theater             5183100.0
#                                    Bereichsübergreifend     4841700.0
# Kulturschaffende                   Musik                    3831200.0
# Kulturunternehmen gemeinnützig     Tanz/Theater             2579300.0
# Kulturschaffende                   Tanz/Theater             1555800.0
# Kulturunternehmen gemeinnützig     Bereichsübergreifend     1352000.0
#                                    Museen                   1268200.0
#                                    Bildende Kunst            980400.0
#                                    Film                      711300.0
# Kulturschaffende                   Bildende Kunst            484000.0
# Kulturunternehmen gemeinnützig     Kino                      381500.0
# Kulturschaffende                   Bereichsübergreifend      314100.0
#                                    Film                      232100.0
# Kulturunternehmen gemeinnützig     Klubs und Konzertlokale   231500.0
#                                    Design                    162900.0
# Kulturschaffende                   Design                    114200.0
# Kulturunternehmen gemeinnützig     Literatur                 106700.0
# Kulturunternehmen gewinnorientiert Design                     84000.0
# Kulturschaffende                   Literatur                  65000.0
# Kulturunternehmen gewinnorientiert Museen                     24200.0
#                                    Literatur                   7800.0
#
#                                                              differenz
# Kategorie                          Sparte
# Kulturunternehmen gewinnorientiert Musik                   -14411300.0
#                                    Klubs und Konzertlokale -14750700.0
#                                    Film                     -3800600.0
#                                    Kino                    -12339300.0
# Kulturunternehmen gemeinnützig     Musik                    -2856500.0
# Kulturunternehmen gewinnorientiert Tanz/Theater             -3819100.0
#                                    Bereichsübergreifend     -4576300.0
# Kulturschaffende                   Musik                    -4823000.0
# Kulturunternehmen gemeinnützig     Tanz/Theater             -1800200.0
# Kulturschaffende                   Tanz/Theater             -2305300.0
# Kulturunternehmen gemeinnützig     Bereichsübergreifend      -877100.0
#                                    Museen                   -1333300.0
#                                    Bildende Kunst            -952600.0
#                                    Film                      -421900.0
# Kulturschaffende                   Bildende Kunst           -1234100.0
# Kulturunternehmen gemeinnützig     Kino                      -536700.0
# Kulturschaffende                   Bereichsübergreifend      -447900.0
#                                    Film                      -285200.0
# Kulturunternehmen gemeinnützig     Klubs und Konzertlokale   -230800.0
#                                    Design                      22900.0
# Kulturschaffende                   Design                    -180900.0
# Kulturunternehmen gemeinnützig     Literatur                  -39500.0
# Kulturunternehmen gewinnorientiert Design                    -144000.0
# Kulturschaffende                   Literatur                 -238200.0
# Kulturunternehmen gewinnorientiert Museen                     -53100.0
#                                    Literatur                  -34000.0

# %% [markdown]
# ### Was wurde abgelehent?

# %%
df_kat = df_ab.groupby('Kategorie').sum()
df_kat['differenz'] = df_kat['Beschluss']-df_kat['Nachgefragt']
df_kat
# Out:
#                                     Nachgefragt  Beschluss   differenz
# Kategorie
# Kulturschaffende                        3357900        0.0  -3357900.0
# Kulturunternehmen gemeinnützig          3394800        0.0  -3394800.0
# Kulturunternehmen gewinnorientiert     15917500        0.0 -15917500.0

# %%
df_sparte = df_ab.groupby('Sparte').sum()
df_sparte['differenz'] = df_sparte['Beschluss']-df_sparte['Nachgefragt']
df_sparte.sort_values('Beschluss',ascending=False)
# Out:
#                          Nachgefragt  Beschluss  differenz
# Sparte
# Bereichsübergreifend         8301500        0.0 -8301500.0
# Bildende Kunst                787700        0.0  -787700.0
# Design                        882200        0.0  -882200.0
# Film                         1376000        0.0 -1376000.0
# Kino                          657100        0.0  -657100.0
# Klubs und Konzertlokale      3919900        0.0 -3919900.0
# Literatur                      41800        0.0   -41800.0
# Museen                        143800        0.0  -143800.0
# Musik                        4050800        0.0 -4050800.0
# Tanz/Theater                 2509400        0.0 -2509400.0

# %%
df_sparte = df_ab.groupby(['Kategorie','Sparte']).sum()
df_sparte['differenz'] = df_sparte['Beschluss']-df_sparte['Nachgefragt']
df_sparte.sort_values('Beschluss',ascending=False)
# Out:
#                                                             Nachgefragt  \
# Kategorie                          Sparte
# Kulturschaffende                   Bereichsübergreifend           67000
#                                    Bildende Kunst                530800
# Kulturunternehmen gewinnorientiert Musik                        2917100
#                                    Museen                         17800
#                                    Literatur                       4100
#                                    Klubs und Konzertlokale      3919900
#                                    Kino                          657100
#                                    Film                          727100
#                                    Design                        423100
#                                    Bildende Kunst                207200
#                                    Bereichsübergreifend         5489000
# Kulturunternehmen gemeinnützig     Tanz/Theater                  367800
#                                    Musik                          38100
#                                    Museen                        126000
#                                    Film                           65900
#                                    Design                          1800
#                                    Bildende Kunst                 49700
#                                    Bereichsübergreifend         2745500
# Kulturschaffende                   Tanz/Theater                  586500
#                                    Musik                        1095600
#                                    Literatur                      37700
#                                    Film                          583000
#                                    Design                        457300
# Kulturunternehmen gewinnorientiert Tanz/Theater                 1555100
#
#                                                             Beschluss  \
# Kategorie                          Sparte
# Kulturschaffende                   Bereichsübergreifend           0.0
#                                    Bildende Kunst                 0.0
# Kulturunternehmen gewinnorientiert Musik                          0.0
#                                    Museen                         0.0
#                                    Literatur                      0.0
#                                    Klubs und Konzertlokale        0.0
#                                    Kino                           0.0
#                                    Film                           0.0
#                                    Design                         0.0
#                                    Bildende Kunst                 0.0
#                                    Bereichsübergreifend           0.0
# Kulturunternehmen gemeinnützig     Tanz/Theater                   0.0
#                                    Musik                          0.0
#                                    Museen                         0.0
#                                    Film                           0.0
#                                    Design                         0.0
#                                    Bildende Kunst                 0.0
#                                    Bereichsübergreifend           0.0
# Kulturschaffende                   Tanz/Theater                   0.0
#                                    Musik                          0.0
#                                    Literatur                      0.0
#                                    Film                           0.0
#                                    Design                         0.0
# Kulturunternehmen gewinnorientiert Tanz/Theater                   0.0
#
#                                                             differenz
# Kategorie                          Sparte
# Kulturschaffende                   Bereichsübergreifend      -67000.0
#                                    Bildende Kunst           -530800.0
# Kulturunternehmen gewinnorientiert Musik                   -2917100.0
#                                    Museen                    -17800.0
#                                    Literatur                  -4100.0
#                                    Klubs und Konzertlokale -3919900.0
#                                    Kino                     -657100.0
#                                    Film                     -727100.0
#                                    Design                   -423100.0
#                                    Bildende Kunst           -207200.0
#                                    Bereichsübergreifend    -5489000.0
# Kulturunternehmen gemeinnützig     Tanz/Theater             -367800.0
#                                    Musik                     -38100.0
#                                    Museen                   -126000.0
#                                    Film                      -65900.0
#                                    Design                     -1800.0
#                                    Bildende Kunst            -49700.0
#                                    Bereichsübergreifend    -2745500.0
# Kulturschaffende                   Tanz/Theater             -586500.0
#                                    Musik                   -1095600.0
#                                    Literatur                 -37700.0
#                                    Film                     -583000.0
#                                    Design                   -457300.0
# Kulturunternehmen gewinnorientiert Tanz/Theater            -1555100.0

# %% [markdown]
# ### Wie lange dauerten die Gesuche

# %%
df['entscheiddauer'] = pd.to_datetime(df['Beschlussdatum'])-pd.to_datetime(df['Eingangsdatum'])
df['entscheiddauer'] = df['entscheiddauer'].dt.days.astype(int)
"Im Schnitt dauerte das Bearbeiten eines Gesuches: " + str(df.entscheiddauer.mean()) + " Tage"
# Out:
# 'Im Schnitt dauerte das Bearbeiten eines Gesuches: 104.23463687150839 Tage'

# %%
df[['Kategorie', 'entscheiddauer']].groupby('Kategorie').mean()
# Out:
#                                     entscheiddauer
# Kategorie
# Kulturschaffende                        102.178189
# Kulturunternehmen gemeinnützig          109.200000
# Kulturunternehmen gewinnorientiert      106.974576

# %%
df[['Sparte', 'entscheiddauer']].groupby('Sparte').mean()
# Out:
#                          entscheiddauer
# Sparte
# Bereichsübergreifend         102.612903
# Bildende Kunst               102.673077
# Design                        97.344828
# Film                         105.644860
# Kino                         101.633333
# Klubs und Konzertlokale       93.658228
# Literatur                    103.659091
# Museen                       102.176471
# Musik                        105.250324
# Tanz/Theater                 106.205882
